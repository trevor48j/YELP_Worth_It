# %%
# Import dependencies
import pandas as pd
import re
import time
import pymongo
from bs4 import BeautifulSoup
from requests import get
from random import randint
from pymongo import MongoClient

# %%
# --- EXTRACT ---

# Set 'restaurant_list' to store information scraped from source website
restaurant_list = []

# Set a for loop to go through the Yelp website from page 1 through 10 using BeautifulSoup to extract HTML code and pull information related to Resturant Name, Cuisine Style, Price, and Rating.
url = "https://www.yelp.com/search?find_desc=Restaurants&find_loc=West%20Hollywood%2C%20CA&start="
for page in range(0,110,10):
    response = get(url+str(page))
    html = response.text
    soup = BeautifulSoup(html,"html.parser")

    rl = re.compile("list*")
    restaurant_ul = soup.find_all('ul', class_=rl)
    for r_ul in restaurant_ul:
        border = re.compile("border*")
        restaurant_li = r_ul.find_all('li', class_=border)

        for restaurant in restaurant_li:
            container = re.compile("container*")
            aux = restaurant.find_all('div', class_=container)

            if len(aux) == 3:
                restaurant_dict = {}
                
                name = re.compile("businessNam*")
                restaurant_name = restaurant.find_all('div', class_=name)
                try:
                    restaurant_dict['name'] = restaurant_name[0].find('a').text     
                except:
                    restaurant_dict['name'] = None

                stars = re.compile("i-stars*")
                restaurant_stars = restaurant.find_all('div', class_=stars)
                try:
                    restaurant_dict['stars'] = restaurant_stars[0]["aria-label"]
                except:
                    restaurant_dict['stars'] = None
                    
                price = re.compile("priceRange*")
                restaurant_price = restaurant.find_all('span', class_=price)
                try:
                    restaurant_dict['price'] = restaurant_price[0].text
                except:
                    restaurant_dict['price'] = None
                    
                
                cuisine = re.compile("text__09f24__2NHRu css-1hx6l2b*")
                restaurant_cuisine = restaurant.find_all('p', class_=cuisine)
                try:
                    restaurant_dict['cuisine'] = restaurant_cuisine[0].text
                except:
                    restaurant_dict['cuisine'] = None
                    
                restaurant_list.append(restaurant_dict)
                    
    time.sleep(randint(1,5))

# Displays the extracted list
restaurant_list
# Out:
# [{'name': 'GRANVILLE',
#   'stars': '4.5 star rating',
#   'price': '$$',
#   'cuisine': 'American (New)'},
#  {'name': 'Soulmate.',
#   'stars': '4 star rating',
#   'price': '$$$',
#   'cuisine': 'Mediterranean'},
#  {'name': 'The Front Yard',
#   'stars': '4 star rating',
#   'price': '$$',
#   'cuisine': 'Tapas/Small Plates'},
#  {'name': 'Tu Madre - West Hollywood',
#   'stars': '4 star rating',
#   'price': '$$',
#   'cuisine': 'Mexican'},
#  {'name': 'Norah',
#   'stars': '4 star rating',
#   'price': '$$',
#   'cuisine': 'American (New)'},
#  {'name': 'Employees Only',
#   'stars': '4 star rating',
#   'price': '$$$',
#   'cuisine': 'Cocktail Bars'},
#  {'name': 'OSTE',
#   'stars': '5 star rating',
#   'price': None,
#   'cuisine': 'Italian'},
#  {'name': 'The Butcher, The Baker, The Cappuccino Maker',
#   'stars': '4 star rating',
#   'price': '$$',
#   'cuisine': 'Breakfast & Brunch'},
#  {'name': 'Republique',
#   'stars': '4 star rating',
#   'price': '$$',
#   'cuisine': 'French'},
#  {'name': 'Conservatory',
#   'stars': '4 star rating',
#   'price': '$$$',
#   'cuisine': 'American (New)'},
#  {'name': 'Rosaline',
#   'stars': '4 star rating',
#   'price': '$$$',
#   'cuisine': 'Peruvian'},
#  {'name': 'Zinqué',
#   'stars': '4 star rating',
#   'price': '$$',
#   'cuisine': 'French'},
#  {'name': 'Gracias Madre - West Hollywood',
#   'stars': '4 star rating',
#   'price': '$$',
#   'cuisine': 'Mexican'},
#  {'name': 'Stache - West Hollywood',
#   'stars': '4.5 star rating',
#   'price': None,
#   'cuisine': 'American (New)'},
#  {'name': 'Jon & Vinny’s Fairfax',
#   'stars': '4 star rating',
#   'price': '$$',
#   'cuisine': 'Italian'},
#  {'name': 'MIAN | 滋味小面',
#   'stars': '4.5 star rating',
#   'price': '$$',
#   'cuisine': 'Chinese'},
#  {'name': 'LOVE',
#   'stars': '5 star rating',
#   'price': '$$',
#   'cuisine': 'Noodles'},
#  {'name': 'Bao Dim Sum House',
#   'stars': '4 star rating',
#   'price': '$$',
#   'cuisine': 'Dim Sum'},
#  {'name': 'Toca Madera',
#   'stars': '4 star rating',
#   'price': '$$$',
#   'cuisine': 'Cocktail Bars'},
#  {'name': 'Pura Vita',
#   'stars': '4.5 star rating',
#   'price': '$$',
#   'cuisine': 'Italian'},
#  {'name': 'Rosaline',
#   'stars': '4 star rating',
#   'price': '$$$',
#   'cuisine': 'Peruvian'},
#  {'name': 'Stache - West Hollywood',
#   'stars': '4.5 star rating',
#   'price': None,
#   'cuisine': 'American (New)'},
#  {'name': 'Jon & Vinny’s Fairfax',
#   'stars': '4 star rating',
#   'price': '$$',
#   'cuisine': 'Italian'},
#  {'name': 'Met Her At A Bar',
#   'stars': '4.5 star rating',
#   'price': '$$',
#   'cuisine': 'Cafes'},
#  {'name': 'Craig’s',
#   'stars': '4 star rating',
#   'price': '$$$',
#   'cuisine': 'American (New)'},
#  {'name': 'MIAN | 滋味小面',
#   'stars': '4.5 star rating',
#   'price': '$$',
#   'cuisine': 'Chinese'},
#  {'name': 'AOC',
#   'stars': '4 star rating',
#   'price': '$$$',
#   'cuisine': 'Wine Bars'},
#  {'name': 'Joan’s on Third',
#   'stars': '4 star rating',
#   'price': '$$',
#   'cuisine': 'Breakfast & Brunch'},
#  {'name': 'Yardbird Table & Bar',
#   'stars': '4.5 star rating',
#   'price': '$$$',
#   'cuisine': 'Southern'},
#  {'name': 'Carlitos Gardel Argentine Steakhouse',
#   'stars': '4.5 star rating',
#   'price': '$$$',
#   'cuisine': 'Argentine'},
#  {'name': 'MIAN | 滋味小面',
#   'stars': '4.5 star rating',
#   'price': '$$',
#   'cuisine': 'Chinese'},
#  {'name': 'Caribbean Soul Kitchen LA',
#   'stars': '5 star rating',
#   'price': None,
#   'cuisine': 'Caribbean'},
#  {'name': 'Dave’s Hot Chicken',
#   'stars': '4.5 star rating',
#   'price': '$$',
#   'cuisine': 'Chicken Shop'},
#  {'name': 'Tesse',
#   'stars': '4 star rating',
#   'price': '$$$',
#   'cuisine': 'Modern European'},
#  {'name': 'Met Him At A Bar',
#   'stars': '4.5 star rating',
#   'price': '$$',
#   'cuisine': 'Italian'},
#  {'name': 'Kochi',
#   'stars': '4.5 star rating',
#   'price': '$$',
#   'cuisine': 'Japanese'},
#  {'name': 'Kazan',
#   'stars': '4.5 star rating',
#   'price': '$$',
#   'cuisine': 'Noodles'},
#  {'name': 'Sweet Chick',
#   'stars': '4 star rating',
#   'price': '$$',
#   'cuisine': 'Southern'},
#  {'name': 'Terrace Restaurant',
#   'stars': '4.5 star rating',
#   'price': None,
#   'cuisine': 'Restaurants'},
#  {'name': 'Bottega Louie - WEHO',
#   'stars': '4 star rating',
#   'price': '$$$',
#   'cuisine': 'Bakeries'},
#  {'name': 'Catch LA',
#   'stars': '3.5 star rating',
#   'price': '$$$',
#   'cuisine': 'Sushi Bars'},
#  {'name': 'Izakaya Tora',
#   'stars': '4.5 star rating',
#   'price': '$$',
#   'cuisine': 'Sushi Bars'},
#  {'name': 'Yojimbo',
#   'stars': '5 star rating',
#   'price': '$$',
#   'cuisine': 'Japanese'},
#  {'name': 'Bacari W 3rd',
#   'stars': '4.5 star rating',
#   'price': '$$',
#   'cuisine': 'American (New)'},
#  {'name': 'Madre',
#   'stars': '4 star rating',
#   'price': '$$',
#   'cuisine': 'Mexican'},
#  {'name': 'Fratelli Cafe',
#   'stars': '4.5 star rating',
#   'price': '$$',
#   'cuisine': 'Coffee & Tea'},
#  {'name': 'Hugo’s',
#   'stars': '4 star rating',
#   'price': '$$',
#   'cuisine': 'American (New)'},
#  {'name': 'Mercado Los Angeles',
#   'stars': '4 star rating',
#   'price': '$$',
#   'cuisine': 'Mexican'},
#  {'name': 'The Rooftop by JG',
#   'stars': '4 star rating',
#   'price': '$$$',
#   'cuisine': 'American (New)'},
#  {'name': 'The Village Idiot',
#   'stars': '4 star rating',
#   'price': '$$',
#   'cuisine': 'Bars'},
#  {'name': 'Guisados',
#   'stars': '4.5 star rating',
#   'price': '$',
#   'cuisine': 'Mexican'},
#  {'name': 'Yuko Kitchen',
#   'stars': '4.5 star rating',
#   'price': '$$',
#   'cuisine': 'Japanese'},
#  {'name': 'Grain Traders',
#   'stars': '5 star rating',
#   'price': '$$',
#   'cuisine': 'American (New)'},
#  {'name': '1 Kitchen by Chris Crary',
#   'stars': '4 star rating',
#   'price': None,
#   'cuisine': 'American (New)'},
#  {'name': 'Ippudo',
#   'stars': '4 star rating',
#   'price': '$$',
#   'cuisine': 'Ramen'},
#  {'name': 'Warrior',
#   'stars': '4.5 star rating',
#   'price': '$$',
#   'cuisine': 'Lounges'},
#  {'name': 'Pinches Tacos',
#   'stars': '4 star rating',
#   'price': '$$',
#   'cuisine': 'Mexican'},
#  {'name': 'Blu Jam Café',
#   'stars': '4 star rating',
#   'price': '$$',
#   'cuisine': 'American (New)'},
#  {'name': 'Comoncy',
#   'stars': '4.5 star rating',
#   'price': '$$',
#   'cuisine': 'Coffee & Tea'},
#  {'name': 'Il Cielo',
#   'stars': '4 star rating',
#   'price': '$$$',
#   'cuisine': 'Italian'},
#  {'name': 'The Rooftop by JG',
#   'stars': '4 star rating',
#   'price': '$$$',
#   'cuisine': 'American (New)'},
#  {'name': 'Spartina',
#   'stars': '4 star rating',
#   'price': '$$$',
#   'cuisine': 'Italian'},
#  {'name': 'Issima',
#   'stars': '4 star rating',
#   'price': None,
#   'cuisine': 'Mediterranean'},
#  {'name': 'Son of a Gun',
#   'stars': '4 star rating',
#   'price': '$$$',
#   'cuisine': 'Seafood'},
#  {'name': 'Kitchen24',
#   'stars': '3.5 star rating',
#   'price': '$$',
#   'cuisine': 'Breakfast & Brunch'},
#  {'name': 'Il Cielo',
#   'stars': '4 star rating',
#   'price': '$$$',
#   'cuisine': 'Italian'},
#  {'name': 'Fresh Corn Grill',
#   'stars': '4.5 star rating',
#   'price': '$$',
#   'cuisine': 'Pizza'},
#  {'name': 'Madre',
#   'stars': '4 star rating',
#   'price': '$$',
#   'cuisine': 'Mexican'},
#  {'name': 'Fratelli Cafe',
#   'stars': '4.5 star rating',
#   'price': '$$',
#   'cuisine': 'Coffee & Tea'},
#  {'name': 'Severance',
#   'stars': '4.5 star rating',
#   'price': '$$',
#   'cuisine': 'Wine Bars'},
#  {'name': 'WeHo Bistro',
#   'stars': '4 star rating',
#   'price': '$$',
#   'cuisine': 'French'},
#  {'name': 'Sweet Chick',
#   'stars': '4 star rating',
#   'price': '$$',
#   'cuisine': 'Southern'},
#  {'name': 'A Food Affair',
#   'stars': '4.5 star rating',
#   'price': '$$',
#   'cuisine': 'French'},
#  {'name': 'La Bohème',
#   'stars': '4 star rating',
#   'price': '$$$',
#   'cuisine': 'Bars'},
#  {'name': 'The Little Door',
#   'stars': '4 star rating',
#   'price': '$$$',
#   'cuisine': 'French'},
#  {'name': 'Hollywood Burger',
#   'stars': '4.5 star rating',
#   'price': None,
#   'cuisine': 'Breakfast & Brunch'},
#  {'name': 'Emilia',
#   'stars': '4.5 star rating',
#   'price': None,
#   'cuisine': 'Italian'},
#  {'name': 'Mama Shelter Rooftop Bar',
#   'stars': '3.5 star rating',
#   'price': '$$',
#   'cuisine': 'American (New)'},
#  {'name': 'Pinches Tacos',
#   'stars': '4 star rating',
#   'price': '$$',
#   'cuisine': 'Mexican'},
#  {'name': 'Yojimbo',
#   'stars': '5 star rating',
#   'price': '$$',
#   'cuisine': 'Japanese'},
#  {'name': 'Dialog Cafe',
#   'stars': '4.5 star rating',
#   'price': '$$',
#   'cuisine': 'Cafes'},
#  {'name': 'Phorage WeHo',
#   'stars': '4 star rating',
#   'price': '$$',
#   'cuisine': 'Vietnamese'},
#  {'name': 'Barton G The Restaurant - Los Angeles',
#   'stars': '4 star rating',
#   'price': '$$$',
#   'cuisine': 'American (New)'},
#  {'name': 'Caribbean Soul Kitchen LA',
#   'stars': '5 star rating',
#   'price': None,
#   'cuisine': 'Caribbean'},
#  {'name': 'Metztli Taqueria',
#   'stars': '5 star rating',
#   'price': None,
#   'cuisine': 'Tacos'},
#  {'name': 'Prospect Gourmand',
#   'stars': '4.5 star rating',
#   'price': '$$',
#   'cuisine': 'American (New)'},
#  {'name': 'Marco’s Trattoria',
#   'stars': '4 star rating',
#   'price': '$$',
#   'cuisine': 'Italian'},
#  {'name': 'Tasty Noodle House',
#   'stars': '4 star rating',
#   'price': '$$',
#   'cuisine': 'Noodles'},
#  {'name': 'Kazan',
#   'stars': '4.5 star rating',
#   'price': '$$',
#   'cuisine': 'Noodles'},
#  {'name': 'Bossa Nova on Sunset',
#   'stars': '3.5 star rating',
#   'price': '$$',
#   'cuisine': 'Brazilian'},
#  {'name': 'Metztli Taqueria',
#   'stars': '5 star rating',
#   'price': None,
#   'cuisine': 'Tacos'},
#  {'name': 'Spago',
#   'stars': '4 star rating',
#   'price': '$$$',
#   'cuisine': 'American (New)'},
#  {'name': 'Issima',
#   'stars': '4 star rating',
#   'price': None,
#   'cuisine': 'Mediterranean'},
#  {'name': 'Cecconi’s West Hollywood',
#   'stars': '3.5 star rating',
#   'price': '$$$',
#   'cuisine': 'Italian'},
#  {'name': 'Phorage WeHo',
#   'stars': '4 star rating',
#   'price': '$$',
#   'cuisine': 'Vietnamese'},
#  {'name': 'Kitchen24',
#   'stars': '3.5 star rating',
#   'price': '$$',
#   'cuisine': 'Breakfast & Brunch'},
#  {'name': 'Casablanca Moroccan kitchens',
#   'stars': '5 star rating',
#   'price': None,
#   'cuisine': 'Moroccan'},
#  {'name': 'EP & LP',
#   'stars': '3 star rating',
#   'price': '$$$',
#   'cuisine': 'Asian Fusion'},
#  {'name': 'Marco’s Trattoria',
#   'stars': '4 star rating',
#   'price': '$$',
#   'cuisine': 'Italian'},
#  {'name': 'Saint Felix',
#   'stars': '4 star rating',
#   'price': '$$',
#   'cuisine': 'American (New)'},
#  {'name': 'Nonna’s Empanadas',
#   'stars': '4 star rating',
#   'price': '$',
#   'cuisine': 'Empanadas'},
#  {'name': 'EP & LP',
#   'stars': '3 star rating',
#   'price': '$$$',
#   'cuisine': 'Asian Fusion'},
#  {'name': 'Connie & Ted’s',
#   'stars': '4 star rating',
#   'price': '$$$',
#   'cuisine': 'Seafood'},
#  {'name': 'Badmaash - Fairfax',
#   'stars': '4 star rating',
#   'price': '$$',
#   'cuisine': 'Indian'},
#  {'name': 'The Phoenix',
#   'stars': '4 star rating',
#   'price': '$$',
#   'cuisine': 'Lounges'},
#  {'name': 'Emilia',
#   'stars': '4.5 star rating',
#   'price': None,
#   'cuisine': 'Italian'},
#  {'name': 'Uovo- Mid-Wilshire',
#   'stars': '4.5 star rating',
#   'price': '$$',
#   'cuisine': 'Italian'},
#  {'name': 'Beauty & Essex',
#   'stars': '4 star rating',
#   'price': '$$$',
#   'cuisine': 'Lounges'},
#  {'name': 'Mama Shelter Rooftop Bar',
#   'stars': '3.5 star rating',
#   'price': '$$',
#   'cuisine': 'American (New)'},
#  {'name': 'Three Borders Brunch & Grill',
#   'stars': '5 star rating',
#   'price': '$$',
#   'cuisine': 'Breakfast & Brunch'}]

# %%
# ---TRANSFORM ---

# Create a dataframe from the extracted list using Pandas 
restaurant_df = pd.DataFrame(restaurant_list)
restaurant_df
# Out:
#                              name            stars price             cuisine
# 0                       GRANVILLE  4.5 star rating    $$      American (New)
# 1                       Soulmate.    4 star rating   $$$       Mediterranean
# 2                  The Front Yard    4 star rating    $$  Tapas/Small Plates
# 3       Tu Madre - West Hollywood    4 star rating    $$             Mexican
# 4                           Norah    4 star rating    $$      American (New)
# ..                            ...              ...   ...                 ...
# 105                        Emilia  4.5 star rating  None             Italian
# 106            Uovo- Mid-Wilshire  4.5 star rating    $$             Italian
# 107                Beauty & Essex    4 star rating   $$$             Lounges
# 108      Mama Shelter Rooftop Bar  3.5 star rating    $$      American (New)
# 109  Three Borders Brunch & Grill    5 star rating    $$  Breakfast & Brunch
#
# [110 rows x 4 columns]

# %%
# Convert the names in the data frame
result_df = restaurant_df[["name","stars","price","cuisine"]]

# Drop 'star rating' from the rating column to be able to manipulate the data
rating = result_df["stars"].replace("star rating","", regex=True)
result_df["star rating"] = rating

# Replace the '$' with integers to manipulate the data
price_1 = result_df["price"].replace("$",1)
result_df["price"] = price_1

price_2 = result_df["price"].replace("$$", 2)
result_df["price"] = price_2

price_3 = result_df["price"].replace("$$$",3)
result_df["price"] = price_3

price_4 = result_df["price"].replace("$$$$",4)
result_df["price"] = price_4

# Convert the rating column to float to manipulate data
result_df['rating'] = result_df['star rating'].astype(float)

# Create a new dataframe with the cleaned data
result_clean_df = result_df[["name", "cuisine", "price", "rating"]]

# Store cleaned dataframe as a csv for visualisations and analysis
result_clean_df.to_csv("Resources/result_clean.csv")

# Display play cleaned dataframe
result_clean_df
# Out:
#                              name             cuisine  price  rating
# 0                       GRANVILLE      American (New)    2.0     4.5
# 1                       Soulmate.       Mediterranean    3.0     4.0
# 2                  The Front Yard  Tapas/Small Plates    2.0     4.0
# 3       Tu Madre - West Hollywood             Mexican    2.0     4.0
# 4                           Norah      American (New)    2.0     4.0
# ..                            ...                 ...    ...     ...
# 105                        Emilia             Italian    NaN     4.5
# 106            Uovo- Mid-Wilshire             Italian    2.0     4.5
# 107                Beauty & Essex             Lounges    3.0     4.0
# 108      Mama Shelter Rooftop Bar      American (New)    2.0     3.5
# 109  Three Borders Brunch & Grill  Breakfast & Brunch    2.0     5.0
#
# [110 rows x 4 columns]

# %%
# --- LOAD ---

# Making a connection with MongoClient
client = MongoClient("mongodb://localhost:27017/")

# Create Database
db = client["YELP_Worth_It"]

# Create Collection
collection = db["CSV Data"]

# Convert dataframe into dictionary
results_dict = result_clean_df.to_dict('index')
results_dict
# Out:
# {0: {'name': 'GRANVILLE',
#   'cuisine': 'American (New)',
#   'price': 2.0,
#   'rating': 4.5},
#  1: {'name': 'Soulmate.',
#   'cuisine': 'Mediterranean',
#   'price': 3.0,
#   'rating': 4.0},
#  2: {'name': 'The Front Yard',
#   'cuisine': 'Tapas/Small Plates',
#   'price': 2.0,
#   'rating': 4.0},
#  3: {'name': 'Tu Madre - West Hollywood',
#   'cuisine': 'Mexican',
#   'price': 2.0,
#   'rating': 4.0},
#  4: {'name': 'Norah',
#   'cuisine': 'American (New)',
#   'price': 2.0,
#   'rating': 4.0},
#  5: {'name': 'Employees Only',
#   'cuisine': 'Cocktail Bars',
#   'price': 3.0,
#   'rating': 4.0},
#  6: {'name': 'OSTE', 'cuisine': 'Italian', 'price': nan, 'rating': 5.0},
#  7: {'name': 'The Butcher, The Baker, The Cappuccino Maker',
#   'cuisine': 'Breakfast & Brunch',
#   'price': 2.0,
#   'rating': 4.0},
#  8: {'name': 'Republique', 'cuisine': 'French', 'price': 2.0, 'rating': 4.0},
#  9: {'name': 'Conservatory',
#   'cuisine': 'American (New)',
#   'price': 3.0,
#   'rating': 4.0},
#  10: {'name': 'Rosaline', 'cuisine': 'Peruvian', 'price': 3.0, 'rating': 4.0},
#  11: {'name': 'Zinqué', 'cuisine': 'French', 'price': 2.0, 'rating': 4.0},
#  12: {'name': 'Gracias Madre - West Hollywood',
#   'cuisine': 'Mexican',
#   'price': 2.0,
#   'rating': 4.0},
#  13: {'name': 'Stache - West Hollywood',
#   'cuisine': 'American (New)',
#   'price': nan,
#   'rating': 4.5},
#  14: {'name': 'Jon & Vinny’s Fairfax',
#   'cuisine': 'Italian',
#   'price': 2.0,
#   'rating': 4.0},
#  15: {'name': 'MIAN | 滋味小面',
#   'cuisine': 'Chinese',
#   'price': 2.0,
#   'rating': 4.5},
#  16: {'name': 'LOVE', 'cuisine': 'Noodles', 'price': 2.0, 'rating': 5.0},
#  17: {'name': 'Bao Dim Sum House',
#   'cuisine': 'Dim Sum',
#   'price': 2.0,
#   'rating': 4.0},
#  18: {'name': 'Toca Madera',
#   'cuisine': 'Cocktail Bars',
#   'price': 3.0,
#   'rating': 4.0},
#  19: {'name': 'Pura Vita', 'cuisine': 'Italian', 'price': 2.0, 'rating': 4.5},
#  20: {'name': 'Rosaline', 'cuisine': 'Peruvian', 'price': 3.0, 'rating': 4.0},
#  21: {'name': 'Stache - West Hollywood',
#   'cuisine': 'American (New)',
#   'price': nan,
#   'rating': 4.5},
#  22: {'name': 'Jon & Vinny’s Fairfax',
#   'cuisine': 'Italian',
#   'price': 2.0,
#   'rating': 4.0},
#  23: {'name': 'Met Her At A Bar',
#   'cuisine': 'Cafes',
#   'price': 2.0,
#   'rating': 4.5},
#  24: {'name': 'Craig’s',
#   'cuisine': 'American (New)',
#   'price': 3.0,
#   'rating': 4.0},
#  25: {'name': 'MIAN | 滋味小面',
#   'cuisine': 'Chinese',
#   'price': 2.0,
#   'rating': 4.5},
#  26: {'name': 'AOC', 'cuisine': 'Wine Bars', 'price': 3.0, 'rating': 4.0},
#  27: {'name': 'Joan’s on Third',
#   'cuisine': 'Breakfast & Brunch',
#   'price': 2.0,
#   'rating': 4.0},
#  28: {'name': 'Yardbird Table & Bar',
#   'cuisine': 'Southern',
#   'price': 3.0,
#   'rating': 4.5},
#  29: {'name': 'Carlitos Gardel Argentine Steakhouse',
#   'cuisine': 'Argentine',
#   'price': 3.0,
#   'rating': 4.5},
#  30: {'name': 'MIAN | 滋味小面',
#   'cuisine': 'Chinese',
#   'price': 2.0,
#   'rating': 4.5},
#  31: {'name': 'Caribbean Soul Kitchen LA',
#   'cuisine': 'Caribbean',
#   'price': nan,
#   'rating': 5.0},
#  32: {'name': 'Dave’s Hot Chicken',
#   'cuisine': 'Chicken Shop',
#   'price': 2.0,
#   'rating': 4.5},
#  33: {'name': 'Tesse',
#   'cuisine': 'Modern European',
#   'price': 3.0,
#   'rating': 4.0},
#  34: {'name': 'Met Him At A Bar',
#   'cuisine': 'Italian',
#   'price': 2.0,
#   'rating': 4.5},
#  35: {'name': 'Kochi', 'cuisine': 'Japanese', 'price': 2.0, 'rating': 4.5},
#  36: {'name': 'Kazan', 'cuisine': 'Noodles', 'price': 2.0, 'rating': 4.5},
#  37: {'name': 'Sweet Chick',
#   'cuisine': 'Southern',
#   'price': 2.0,
#   'rating': 4.0},
#  38: {'name': 'Terrace Restaurant',
#   'cuisine': 'Restaurants',
#   'price': nan,
#   'rating': 4.5},
#  39: {'name': 'Bottega Louie - WEHO',
#   'cuisine': 'Bakeries',
#   'price': 3.0,
#   'rating': 4.0},
#  40: {'name': 'Catch LA',
#   'cuisine': 'Sushi Bars',
#   'price': 3.0,
#   'rating': 3.5},
#  41: {'name': 'Izakaya Tora',
#   'cuisine': 'Sushi Bars',
#   'price': 2.0,
#   'rating': 4.5},
#  42: {'name': 'Yojimbo', 'cuisine': 'Japanese', 'price': 2.0, 'rating': 5.0},
#  43: {'name': 'Bacari W 3rd',
#   'cuisine': 'American (New)',
#   'price': 2.0,
#   'rating': 4.5},
#  44: {'name': 'Madre', 'cuisine': 'Mexican', 'price': 2.0, 'rating': 4.0},
#  45: {'name': 'Fratelli Cafe',
#   'cuisine': 'Coffee & Tea',
#   'price': 2.0,
#   'rating': 4.5},
#  46: {'name': 'Hugo’s',
#   'cuisine': 'American (New)',
#   'price': 2.0,
#   'rating': 4.0},
#  47: {'name': 'Mercado Los Angeles',
#   'cuisine': 'Mexican',
#   'price': 2.0,
#   'rating': 4.0},
#  48: {'name': 'The Rooftop by JG',
#   'cuisine': 'American (New)',
#   'price': 3.0,
#   'rating': 4.0},
#  49: {'name': 'The Village Idiot',
#   'cuisine': 'Bars',
#   'price': 2.0,
#   'rating': 4.0},
#  50: {'name': 'Guisados', 'cuisine': 'Mexican', 'price': 1.0, 'rating': 4.5},
#  51: {'name': 'Yuko Kitchen',
#   'cuisine': 'Japanese',
#   'price': 2.0,
#   'rating': 4.5},
#  52: {'name': 'Grain Traders',
#   'cuisine': 'American (New)',
#   'price': 2.0,
#   'rating': 5.0},
#  53: {'name': '1 Kitchen by Chris Crary',
#   'cuisine': 'American (New)',
#   'price': nan,
#   'rating': 4.0},
#  54: {'name': 'Ippudo', 'cuisine': 'Ramen', 'price': 2.0, 'rating': 4.0},
#  55: {'name': 'Warrior', 'cuisine': 'Lounges', 'price': 2.0, 'rating': 4.5},
#  56: {'name': 'Pinches Tacos',
#   'cuisine': 'Mexican',
#   'price': 2.0,
#   'rating': 4.0},
#  57: {'name': 'Blu Jam Café',
#   'cuisine': 'American (New)',
#   'price': 2.0,
#   'rating': 4.0},
#  58: {'name': 'Comoncy',
#   'cuisine': 'Coffee & Tea',
#   'price': 2.0,
#   'rating': 4.5},
#  59: {'name': 'Il Cielo', 'cuisine': 'Italian', 'price': 3.0, 'rating': 4.0},
#  60: {'name': 'The Rooftop by JG',
#   'cuisine': 'American (New)',
#   'price': 3.0,
#   'rating': 4.0},
#  61: {'name': 'Spartina', 'cuisine': 'Italian', 'price': 3.0, 'rating': 4.0},
#  62: {'name': 'Issima',
#   'cuisine': 'Mediterranean',
#   'price': nan,
#   'rating': 4.0},
#  63: {'name': 'Son of a Gun',
#   'cuisine': 'Seafood',
#   'price': 3.0,
#   'rating': 4.0},
#  64: {'name': 'Kitchen24',
#   'cuisine': 'Breakfast & Brunch',
#   'price': 2.0,
#   'rating': 3.5},
#  65: {'name': 'Il Cielo', 'cuisine': 'Italian', 'price': 3.0, 'rating': 4.0},
#  66: {'name': 'Fresh Corn Grill',
#   'cuisine': 'Pizza',
#   'price': 2.0,
#   'rating': 4.5},
#  67: {'name': 'Madre', 'cuisine': 'Mexican', 'price': 2.0, 'rating': 4.0},
#  68: {'name': 'Fratelli Cafe',
#   'cuisine': 'Coffee & Tea',
#   'price': 2.0,
#   'rating': 4.5},
#  69: {'name': 'Severance',
#   'cuisine': 'Wine Bars',
#   'price': 2.0,
#   'rating': 4.5},
#  70: {'name': 'WeHo Bistro', 'cuisine': 'French', 'price': 2.0, 'rating': 4.0},
#  71: {'name': 'Sweet Chick',
#   'cuisine': 'Southern',
#   'price': 2.0,
#   'rating': 4.0},
#  72: {'name': 'A Food Affair',
#   'cuisine': 'French',
#   'price': 2.0,
#   'rating': 4.5},
#  73: {'name': 'La Bohème', 'cuisine': 'Bars', 'price': 3.0, 'rating': 4.0},
#  74: {'name': 'The Little Door',
#   'cuisine': 'French',
#   'price': 3.0,
#   'rating': 4.0},
#  75: {'name': 'Hollywood Burger',
#   'cuisine': 'Breakfast & Brunch',
#   'price': nan,
#   'rating': 4.5},
#  76: {'name': 'Emilia', 'cuisine': 'Italian', 'price': nan, 'rating': 4.5},
#  77: {'name': 'Mama Shelter Rooftop Bar',
#   'cuisine': 'American (New)',
#   'price': 2.0,
#   'rating': 3.5},
#  78: {'name': 'Pinches Tacos',
#   'cuisine': 'Mexican',
#   'price': 2.0,
#   'rating': 4.0},
#  79: {'name': 'Yojimbo', 'cuisine': 'Japanese', 'price': 2.0, 'rating': 5.0},
#  80: {'name': 'Dialog Cafe', 'cuisine': 'Cafes', 'price': 2.0, 'rating': 4.5},
#  81: {'name': 'Phorage WeHo',
#   'cuisine': 'Vietnamese',
#   'price': 2.0,
#   'rating': 4.0},
#  82: {'name': 'Barton G The Restaurant - Los Angeles',
#   'cuisine': 'American (New)',
#   'price': 3.0,
#   'rating': 4.0},
#  83: {'name': 'Caribbean Soul Kitchen LA',
#   'cuisine': 'Caribbean',
#   'price': nan,
#   'rating': 5.0},
#  84: {'name': 'Metztli Taqueria',
#   'cuisine': 'Tacos',
#   'price': nan,
#   'rating': 5.0},
#  85: {'name': 'Prospect Gourmand',
#   'cuisine': 'American (New)',
#   'price': 2.0,
#   'rating': 4.5},
#  86: {'name': 'Marco’s Trattoria',
#   'cuisine': 'Italian',
#   'price': 2.0,
#   'rating': 4.0},
#  87: {'name': 'Tasty Noodle House',
#   'cuisine': 'Noodles',
#   'price': 2.0,
#   'rating': 4.0},
#  88: {'name': 'Kazan', 'cuisine': 'Noodles', 'price': 2.0, 'rating': 4.5},
#  89: {'name': 'Bossa Nova on Sunset',
#   'cuisine': 'Brazilian',
#   'price': 2.0,
#   'rating': 3.5},
#  90: {'name': 'Metztli Taqueria',
#   'cuisine': 'Tacos',
#   'price': nan,
#   'rating': 5.0},
#  91: {'name': 'Spago',
#   'cuisine': 'American (New)',
#   'price': 3.0,
#   'rating': 4.0},
#  92: {'name': 'Issima',
#   'cuisine': 'Mediterranean',
#   'price': nan,
#   'rating': 4.0},
#  93: {'name': 'Cecconi’s West Hollywood',
#   'cuisine': 'Italian',
#   'price': 3.0,
#   'rating': 3.5},
#  94: {'name': 'Phorage WeHo',
#   'cuisine': 'Vietnamese',
#   'price': 2.0,
#   'rating': 4.0},
#  95: {'name': 'Kitchen24',
#   'cuisine': 'Breakfast & Brunch',
#   'price': 2.0,
#   'rating': 3.5},
#  96: {'name': 'Casablanca Moroccan kitchens',
#   'cuisine': 'Moroccan',
#   'price': nan,
#   'rating': 5.0},
#  97: {'name': 'EP & LP',
#   'cuisine': 'Asian Fusion',
#   'price': 3.0,
#   'rating': 3.0},
#  98: {'name': 'Marco’s Trattoria',
#   'cuisine': 'Italian',
#   'price': 2.0,
#   'rating': 4.0},
#  99: {'name': 'Saint Felix',
#   'cuisine': 'American (New)',
#   'price': 2.0,
#   'rating': 4.0},
#  100: {'name': 'Nonna’s Empanadas',
#   'cuisine': 'Empanadas',
#   'price': 1.0,
#   'rating': 4.0},
#  101: {'name': 'EP & LP',
#   'cuisine': 'Asian Fusion',
#   'price': 3.0,
#   'rating': 3.0},
#  102: {'name': 'Connie & Ted’s',
#   'cuisine': 'Seafood',
#   'price': 3.0,
#   'rating': 4.0},
#  103: {'name': 'Badmaash - Fairfax',
#   'cuisine': 'Indian',
#   'price': 2.0,
#   'rating': 4.0},
#  104: {'name': 'The Phoenix',
#   'cuisine': 'Lounges',
#   'price': 2.0,
#   'rating': 4.0},
#  105: {'name': 'Emilia', 'cuisine': 'Italian', 'price': nan, 'rating': 4.5},
#  106: {'name': 'Uovo- Mid-Wilshire',
#   'cuisine': 'Italian',
#   'price': 2.0,
#   'rating': 4.5},
#  107: {'name': 'Beauty & Essex',
#   'cuisine': 'Lounges',
#   'price': 3.0,
#   'rating': 4.0},
#  108: {'name': 'Mama Shelter Rooftop Bar',
#   'cuisine': 'American (New)',
#   'price': 2.0,
#   'rating': 3.5},
#  109: {'name': 'Three Borders Brunch & Grill',
#   'cuisine': 'Breakfast & Brunch',
#   'price': 2.0,
#   'rating': 5.0}}

# %%
# Insert data into MongoDB
for result in results_dict.values():
    collection.insert_one(result)
